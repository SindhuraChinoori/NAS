# %% [markdown]
# # National Achievement Survey
#
# ## Reading data from csv file

# %%
import pandas as pd #importing libraries
pupil_marks = pd.read_csv("E:/gramener/training/nas-pupil-marks.csv") # reading pupil data from csv file
pupil_marks.head() #printing head
# Out:
#          STUID State  District  Gender  Age  Category  Same language  \
# 0  11011001001    AP         1       1    3         3              1
# 1  11011001002    AP         1       2    3         4              2
# 2  11011001003    AP         1       2    3         4              2
# 3  11011001004    AP         1       2    3         3              2
# 4  11011001005    AP         1       2    3         3              2
#
#    Siblings  Handicap  Father edu    ...     Express science views  Watch TV  \
# 0         5         2           1    ...                         3         3
# 1         5         2           2    ...                         3         4
# 2         5         2           1    ...                         3         4
# 3         4         2           1    ...                         3         4
# 4         5         2           1    ...                         3         2
#
#    Read magazine  Read a book  Play games Help in household  Maths %  \
# ...

# %%
nas_col = pd.read_csv("E:/gramener/training/nas-columns.csv") # reading pupil data from csv file
nas_col.head() #printing head
# Out:
#     Name    Rename   Type
# 0    PQ2    Gender  Group
# 1   DIST  District    NaN
# 2  STATE     State    NaN
# 3    PQ3       Age  Group
# 4    PQ4  Category    NaN

# %%
nas_label = pd.read_csv("E:/gramener/training/nas-labels.csv") # reading pupil data from csv file
nas_label.head() #printing head
# Out:
#    Column      Name Level    Rename
# 0  Gender       Boy     1       Boy
# 1  Gender      Girl     2      Girl
# 2     Age  12 years     2  12 years
# 3     Age  13 years     3  13 years
# 4     Age  14 years     4  14 years

# %%
import numpy as np
pupil_marks['Total %'] = pupil_marks[['Maths %','Reading %','Science %','Social %']].mean(axis=1)

pupil_marks['Distance'].replace([0,2,3,4,1],[np.nan,'1-3 km','3-5 km','More than 5 km','Up to 1 km'],inplace=True)
# pupil_marks[['Maths %','Reading %','Science %','Social %']].sum(axis=1)
pupil_marks.head()
# Out:
#          STUID State  District  Gender  Age  Category  Same language  \
# 0  11011001001    AP         1       1    3         3              1
# 1  11011001002    AP         1       2    3         4              2
# 2  11011001003    AP         1       2    3         4              2
# 3  11011001004    AP         1       2    3         3              2
# 4  11011001005    AP         1       2    3         3              2
#
#    Siblings  Handicap  Father edu   ...     Watch TV  Read magazine  \
# 0         5         2           1   ...            3              4
# 1         5         2           2   ...            4              4
# 2         5         2           1   ...            4              3
# 3         4         2           1   ...            4              3
# 4         5         2           1   ...            2              3
#
#    Read a book  Play games  Help in household Maths %  Reading %  Science %  \
# ...

# %%
f = pupil_marks.groupby(['Distance']).agg({'Maths %': 'mean','Reading %': 'mean','Science %': 'mean','Social %': 'mean','Total %': 'mean'})
# f.max() - f.min()
# f.max()
# pd.DataFrame([f.max(), f.min()], columns=["max", "min"])
f
df = pd.DataFrame(f)

# %%
# df['Maths %']  = df['Maths %'] - df['Maths %'].min()
cols_of_interest = list(df.columns.values)
# df.rename()
df2 = df[cols_of_interest] - df[cols_of_interest].min()
df2
# Out:
#                  Maths %  Reading %  Science %  Social %   Total %
# Distance
# 1-3 km          1.733580   0.622786   0.894519  0.883549  0.804349
# 3-5 km          0.495266   0.578377   0.000000  0.000000  0.000000
# More than 5 km  0.000000   1.234472   0.521359  0.277524  0.282075
# Up to 1 km      2.171077   0.000000   0.281461  0.579180  0.522084

# %%
# import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

# ax = sns.barplot(x="Total %", data=df)
# plt.figure(figsize=(8,4))
for col in df.columns.values:
    fig, ax =plt.subplots(ncols=2,figsize=(15,4))
    sns.barplot(x=col, y = df2.index, data=df2,ax=ax[0])

    # ax.set(xlim=(0.5,4.5))
    # ax[0].set_ylabel('distance')
    ax[0].set_xlabel('Impact of distance on '+col)
    #plt.show()
    sns.barplot(y=col, x = df.index, data=df, ax=ax[1])
    
    plt.xticks(rotation=45)

    plt.show()
